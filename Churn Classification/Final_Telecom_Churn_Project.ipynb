# %% [markdown]
# # What is Churn?
#
#
# - **Defination :**
#     - ***Churn is measurnment of the percentage of accounts that cancel or choose not to renew their subscriptions. A high churn rate can negatively impact Monthly Recurring Revenue (MRR) & can also indicate dissatisfaction with a product or service.***
#
#
# - *Churn is the measure of how many customers stop using a product. This can be measured based on actual usage or failure to renew (when the product is sold using a subscription model). Often evaluated for a specific period of time, there can be a monthly, quarterly, or annual churn rate.*
#
#
# - *When new customers begin buying and/or using a product, each new user contributes to a product's growth rate. Inevitably some of those customers will eventually discontinue their usage or cancel their subscription; either beacuse they switched to a competitor or alternative solution, no longer need to product's functions, they are unhappy with their user experience, or they can no longer afford or justify the cost. The customers that stop using/paying are the "churn" for a given period of time.*
#
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#
# # How is Churn Calculated?
#
#
# - *In the most simplistic form, the churn rate is the percentage of total customers that stop using/paying over a period of time. So, if there were 10,000 total customers in March & 1,000 of them stopped being customers, the monthly churn rate would be 10%.*
#
#
# - **Formula :**
# $$\text{Churn Rate} = \frac{\text{Number of customers lost in a given time period}}{\text{Total number of customers at the beginning of the time period}}$$
#
#
# $$\text{Churn Rate (as a percentage)} = \frac{\text{Number of customers lost in a given time period}}{\text{Total number of customers at the beginning of the time period}} \times 100$$
#
#
# - *But where & when you start counting & calculating can impact the math & eventual churn rate. For example, if the product began March with 8,000 customers & added 2,000 new customers that month, should the 1,000 customers who quit be divided by 10,000 (total customers at the end of the month) or 9,000 (total customers at the beginning of the month, factoring in the addition of 2,000 & the substraction of 1,000) or 8,000 (total customers at the beginning of the month, regardless of how many were added)? That could change the monthly churn rate from 10% to 11.1% or 12.5%.*
#
#
# ---------------------------------------------------------------------------------------------------------------------------
# ## Customers churn for various reasons.
# - Customer frustrated with product user experience :
#     - Dissatisfaction with usability, lack of features, or persistent bugs & performance issues can drive a customer away.
# - The customer has found/switched to an alternative solution :
#     - This may be direct competitor or an indirect alternative that is free or already available (i.e. instead of a reminder app the customer will just write down their notes on paper).
# - Damage to product reputstion :
#     - This could be a cybersecurity issue, noteworthy performance problems, terrible customer service or bad acts by the company or company employees.
#
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#
# # How Can You Reduce Churn?
#
#
# *Churn is reduced by increasing the perceived value proposition of the product to current users. This can be achieved in a number of ways since the value is determined based on several factors*
#
#
# **1. Make sure customers get the most out of the product :**
#     - *It doesn't matter how much a product can do if end users aren't aware of those capabilities, can't figure out how to use them & aren't positioned for success. Invest in onboarding, training, tutorials, contextual help, & proactive customer support to increase the chances that customers will understand how to actually use the product to its fullest.*
#
#
# **2. Price based on value :**
#     - *Customers don't care about vendor profit margins, growth rates, & revenue targets; they want to pay what they think a product is actually worth to them. Use customer-focused pricing strategies for yous product that present a clear ROI to users.*
#
#
# **3. Don’t take customers for granted :**
#     - *No renewal should be considered a given and any customer may cancel at a moment’s notice, so continually engage customers to understand their likes and dislikes as well as what could improve their experience.*
#
#
# **4. Lean into your best customers.**
#
# **5. Be proactive with communication.**
#
# **6. Define a roadmap for your new customers.**
#
# **7. Offer incentives.**
#
# **8. Ask for feedback often.**
#
# **9. Analyze churn when it happens.**
#
# **10. Stay competitive.**
#
# **11. Provide excellent customer service.**
#
# **12. Create a community around your customers.**
#
# **13. Focus on attracting the right customers.**
#
# **14. Make it easy for customers to stay long term.**
#
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#
# # Pros & Cons of Churn :
#
#
# ### Pros :
# - *Provides clarity on the quality of the business*
# - *Indicates whether customers are satisfied or dissatisfied with the product or service*
# - *Allows for comparison with competitors to gauge an acceptable level of churn*
# - *Easy to calculate*
#
#
# ### Cons :
# - *Does not provide clarity on the types of customers leaving : new versus old*
# - *Does not differentiate between types of companies in industry comparison : startups, growing & mature*
#
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#
# # What is  a Good Churn Rate?
#
#
# - *Ideally, a churn rate of zero would be the best churn rate, as that would indicate a business is not losing any subscribers; however, that is never the reality. A business will always lose subscribers for one reason or another.*
# - *In this case, it is important to compare the churn rate of the business to its industry's average churn rate, taking into consideration if the business is new or mature. Knowing an industry's churn rate versus that of the business is the only way to understand if a churn rate is acceptable or poor. Every industry has a different business model & therefore, will have different acceptable churn rates.*
#
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#
# # What Does a High Churn Rate Mean?
#
#
# *A high churn rate indicates that a business is losing significant customers, certainly more than it is bringing in. This would mean that the business is doing something worng, whether that be delivering a poor product, having poor customer service, or a host of other negative reasons that would explain why it is losing customers fast. A high churn rate would most likely mean a company is suffering significant losses.*
#
#
# =========================================================================================================================

# %% [markdown]
# # Problem Statement :
# - *The Project will aim to bulid the model which can predict the customer will Churn or not.*
#
# - *The project will also aim to provide actionable insights to help the company improve customer satisfaction & reduce churn rates.*

# %%
# Importing all usefull libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from scipy.stats import iqr
from sklearn.feature_selection import SelectKBest, chi2, RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Ignore anoying warnings
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
# C:\Users\Vinaykumar\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Vinaykumar\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\Vinaykumar\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Loading the Telecom Churn dataset
telecom = pd.read_csv("Churn.csv", index_col=0)

# %% [markdown]
# - *Selcting `Unnamed:0` column as index column.*

# %%
# Showing first 5 rows from given dataset
telecom.head()
# Out:
#   state      area.code  account.length voice.plan  voice.messages intl.plan  \
# 1    KS  area_code_415             128        yes              25        no
# 2    OH  area_code_415             107        yes              26        no
# 3    NJ  area_code_415             137         no               0        no
# 4    OH  area_code_408              84         no               0       yes
# 5    OK  area_code_415              75         no               0       yes
#
#    intl.mins  intl.calls  intl.charge  day.mins  day.calls day.charge  \
# 1       10.0           3         2.70     265.1        110      45.07
# 2       13.7           3         3.70     161.6        123      27.47
# 3       12.2           5         3.29     243.4        114      41.38
# 4        6.6           7         1.78     299.4         71       50.9
# 5       10.1           3         2.73     166.7        113      28.34
#
#   eve.mins  eve.calls  eve.charge  night.mins  night.calls  night.charge  \
# ...

# %%
# Showing last 5 rows from given dataset
telecom.tail()
# Out:
#      state      area.code  account.length voice.plan  voice.messages  \
# 4996    HI  area_code_408              50        yes              40
# 4997    WV  area_code_415             152         no               0
# 4998    DC  area_code_415              61         no               0
# 4999    DC  area_code_510             109         no               0
# 5000    VT  area_code_415              86        yes              34
#
#      intl.plan  intl.mins  intl.calls  intl.charge  day.mins  day.calls  \
# 4996        no        9.9           5         2.67     235.7        127
# 4997        no       14.7           2         3.97     184.2         90
# 4998        no       13.6           4         3.67     140.6         89
# 4999        no        8.5           6         2.30     188.8         67
# 5000        no        9.3          16         2.51     129.4        102
#
#      day.charge eve.mins  eve.calls  eve.charge  night.mins  night.calls  \
# ...

# %% [markdown]
# ## *Exploratory Data Analysis*  [EDA] :

# %%
# Dimensions of given dataset
telecom.shape
# Out:
# (5000, 20)

# %% [markdown]
# - *Telecom data set contain 5000 rows & 20 columns, in which 19 are independent column & 1 is target  variable.*

# %%
# Renaming the column names for better understanding
telecom = telecom.rename(columns={'area.code':'area_code','account.length':'account_length','voice.plan':'voice_plan',
                                  'voice.messages':'voice_messages','intl.plan':'intl_plan','intl.mins':'intl_mins',
                                  'intl.calls':'intl_calls','intl.charge':'intl_charge','day.mins':'day_mins',
                                  'day.calls':'day_calls','day.charge':'day_charge','eve.mins':'eve_mins',
                                  'eve.calls':'eve_calls','eve.charge':'eve_charge','night.mins':'night_mins',
                                  'night.calls':'night_calls','night.charge':'night_charge',
                                  'customer.calls':'customer_calls'})

# %%
# Summary of dataset
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 1 to 5000
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           5000 non-null   object
#  1   area_code       5000 non-null   object
#  2   account_length  5000 non-null   int64
#  3   voice_plan      5000 non-null   object
#  4   voice_messages  5000 non-null   int64
#  5   intl_plan       5000 non-null   object
#  6   intl_mins       5000 non-null   float64
#  7   intl_calls      5000 non-null   int64
#  8   intl_charge     5000 non-null   float64
#  9   day_mins        5000 non-null   float64
#  10  day_calls       5000 non-null   int64
#  11  day_charge      5000 non-null   object
#  12  eve_mins        5000 non-null   object
#  13  eve_calls       5000 non-null   int64
#  14  eve_charge      5000 non-null   float64
#  15  night_mins      5000 non-null   float64
#  16  night_calls     5000 non-null   int64
# ...

# %% [markdown]
# - *No missing values. but the datatype of the colums are different, some showing object.*

# %%
# Looking for null values
telecom.isnull().any().any()
# Out:
# False

# %% [markdown]
# - *In given telecom dataset there are some Nan values are present in `"day.charge"` & `"eve.mins"` columns, but we could not find this Nan values. To detect those Nan values first convert type of those columns form object to float64 type.*

# %%
# Converting object columns into float64 type column

telecom['day_charge'] = telecom['day_charge'].astype('float64')

telecom['eve_mins'] = telecom['eve_mins'].astype('float64')

# %%
# Checking the type of column are changed or not

print(telecom['day_charge'].dtypes)

print(telecom['eve_mins'].dtypes)
# Out:
# float64
# float64

# %%
# Looking for Nan values
telecom.isna().sum()
# Out:
# state              0
# area_code          0
# account_length     0
# voice_plan         0
# voice_messages     0
# intl_plan          0
# intl_mins          0
# intl_calls         0
# intl_charge        0
# day_mins           0
# day_calls          0
# day_charge         7
# eve_mins          24
# eve_calls          0
# eve_charge         0
# night_mins         0
# night_calls        0
# night_charge       0
# customer_calls     0
# churn              0
# dtype: int64

# %% [markdown]
# - *After changing data type we see `Nan` values are present.*
# - *7 Nan values are present in `"day_charge"` column.*
# - *24 Nan values are present in `"eve_mins"` column.*

# %%
# Replacing Nan values with median of that columns.

telecom['day_charge'].fillna(telecom['day_charge'].median(), inplace=True)

telecom['eve_mins'].fillna(telecom['eve_mins'].median(), inplace=True)

# %%
# Again chacking for Nan values

telecom.isna().any().any()
# Out:
# False

# %% [markdown]
# - *We can see that the Nan values are replaced with median values.*
# - *Dataset not contains any missing values.*

# %%
# Creating function for overview of dataset

def dataoveriew(telecom, message):
    print(f'{message}:\n')
    print("Rows:", telecom.shape[0])
    print("\nNumber of columns:", telecom.shape[1])
    print("\nColumns:")
    print(telecom.columns.tolist())
    print("\nMissing values:", telecom.isnull().sum().values.sum())
    print("\nUnique values:")
    print(telecom.nunique())
    
# Using that function to get overview of telecom dataset 
dataoveriew(telecom, 'Overiew of the Telecom dataset')
# Out:
# Overiew of the Telecom dataset:
#
# Rows: 5000
#
# Number of columns: 20
#
# Columns:
# ['state', 'area_code', 'account_length', 'voice_plan', 'voice_messages', 'intl_plan', 'intl_mins', 'intl_calls', 'intl_charge', 'day_mins', 'day_calls', 'day_charge', 'eve_mins', 'eve_calls', 'eve_charge', 'night_mins', 'night_calls', 'night_charge', 'customer_calls', 'churn']
#
# Missing values: 0
#
# Unique values:
# state               51
# area_code            3
# account_length     218
# voice_plan           2
# voice_messages      48
# intl_plan            2
# intl_mins          170
# intl_calls          21
# intl_charge        170
# day_mins          1961
# day_calls          123
# day_charge        1961
# eve_mins          1876
# eve_calls          126
# eve_charge        1659
# night_mins        1853
# night_calls        131
# night_charge      1028
# customer_calls      10
# churn                2
# dtype: int64

# %%
# Checking basic stats from all numerical columns 
telecom.describe().T
# Out:
#                  count        mean        std  min     25%     50%     75%  \
# account_length  5000.0  100.258600  39.694560  1.0   73.00  100.00  127.00
# voice_messages  5000.0    7.755200  13.546393  0.0    0.00    0.00   17.00
# intl_mins       5000.0   10.261780   2.761396  0.0    8.50   10.30   12.00
# intl_calls      5000.0    4.435200   2.456788  0.0    3.00    4.00    6.00
# intl_charge     5000.0    2.771196   0.745514  0.0    2.30    2.78    3.24
# day_mins        5000.0  180.288900  53.894699  0.0  143.70  180.10  216.20
# day_calls       5000.0  100.029400  19.831197  0.0   87.00  100.00  113.00
# day_charge      5000.0   30.653454   9.159936  0.0   24.43   30.62   36.75
# eve_mins        5000.0  200.582340  50.433144  0.0  166.60  201.00  233.90
# eve_calls       5000.0  100.191000  19.826496  0.0   87.00  100.00  114.00
# eve_charge      5000.0   17.054322   4.296843  0.0   14.14   17.09   19.90
# ...

# %% [markdown]
# - zero null values.
# - outliers present in some columns.
# - some column are normally distrubuted, some are right skewed, some are left skewed also.

# %%
# Checking stats from non-numerical columns, we use include parameter

telecom.describe(include=['object','bool'])
# Out:
#        state      area_code voice_plan intl_plan churn
# count   5000           5000       5000      5000  5000
# unique    51              3          2         2     2
# top       WV  area_code_415         no        no    no
# freq     158           2495       3677      4527  4293

# %%
# Looking for duplicates

telecom[telecom.duplicated()].any().any()
# Out:
# False

# %% [markdown]
# - *No duplicate values are present in given telecom dataset.*

# %%
# Counting "churn" column values

telecom['churn'].value_counts()
# Out:
# no     4293
# yes     707
# Name: churn, dtype: int64

# %% [markdown]
# - *In above counts we say that 4293 users out of 5000 are loyal & 707 users have not renew their subscriptions.*

# %% [markdown]
# # Visualizations :

# %%
# Pie chart
labels = ["No", "Yes"]
explode = (0, 0.1)  # only "explode" the second slice (i.e. 'Yes')

# depicting the visualization 
fig = plt.figure(figsize=(20,10),dpi=250) 
ax = fig.add_axes([0,0,1,1]) 

ax.pie(telecom['churn'].value_counts(), 
       labels = labels,
       explode = explode,
       autopct ='%1.2f%%',
       frame = True,
       textprops = dict(color ="black", size=12)) 

ax.axis('equal') 
plt.title('Customer Churn in Telecom Dataset', loc='center', color='black', fontsize='18')
plt.show()

# %% [markdown]
# - *In Telecom Churn dataset, there are 85.86% Loyal `(No)` customers & 14.14% customers `(Yes)` left their subscriptions.*

# %%
# Group the data by state and churn status and count the number of rows
grouped_data = telecom.groupby(['state', 'churn']).size().reset_index(name='count')

# Pivot the data to have state as index, churn status as columns, and count as values
pivot_data = grouped_data.pivot(index='state', columns='churn', values='count')

# Create a stacked bar chart with the pivot data
ax = pivot_data.plot(kind='bar', stacked=True, figsize=(20,10))

# Set the title and axis labels
ax.set_title('Churned Customers by State')
ax.set_xlabel('State')
ax.set_ylabel('Number of Customers')

plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# - *In above barchart we see that `"WV"` state has more loyal (No) customers compare to other states & `"CA"` state having less customers which are loyal than other states.*

# %%
# Group the data by state and churn status and count the number of rows
grouped_data = telecom.groupby(['area_code', 'churn']).size().reset_index(name='count')

# Pivot the data to have state as index, churn status as columns, and count as values
pivot_data = grouped_data.pivot(index='area_code', columns='churn', values='count')

# Create a stacked bar chart with the pivot data
ax = pivot_data.plot(kind='bar', stacked=True, figsize=(20,10))

# Set the title and axis labels
ax.set_title('Churned Customers by Area Code')
ax.set_xlabel('Area Code')
ax.set_ylabel('Number of Customers')

plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# - *In above graph we see that the `area_code_415` having more loyal (No) customers than other areas.*
# - *`area_code_408` & `area_code_510` having equaly churned customers.*

# %% [markdown]
# ## Label Encoding :
# - *`LabelEncoder` can be used to normalize columns.*
# - *It converts catagorical columns into numerical columns.*

# %%
# Droping "state" & "area_code" columns 
telecom.drop(columns=['state','area_code'], inplace=True)

telecom.head()
# Out:
#    account_length voice_plan  voice_messages intl_plan  intl_mins  intl_calls  \
# 1             128        yes              25        no       10.0           3
# 2             107        yes              26        no       13.7           3
# 3             137         no               0        no       12.2           5
# 4              84         no               0       yes        6.6           7
# 5              75         no               0       yes       10.1           3
#
#    intl_charge  day_mins  day_calls  day_charge  eve_mins  eve_calls  \
# 1         2.70     265.1        110       45.07     197.4         99
# 2         3.70     161.6        123       27.47     195.5        103
# 3         3.29     243.4        114       41.38     121.2        110
# 4         1.78     299.4         71       50.90      61.9         88
# 5         2.73     166.7        113       28.34     148.3        122
#
#    eve_charge  night_mins  night_calls  night_charge  customer_calls churn
# ...

# %%
# Creating LabelEncoder object
le = LabelEncoder()

# Selecting only categorical columns
cat_cols = telecom.select_dtypes(include=[object]).columns

# Converting those categorical into numerical columns
telecom[cat_cols] = telecom[cat_cols].apply(lambda col : le.fit_transform(col))

# After performing label encoding showing the dataset
telecom.head()
# Out:
#    account_length  voice_plan  voice_messages  intl_plan  intl_mins  \
# 1             128           1              25          0       10.0
# 2             107           1              26          0       13.7
# 3             137           0               0          0       12.2
# 4              84           0               0          1        6.6
# 5              75           0               0          1       10.1
#
#    intl_calls  intl_charge  day_mins  day_calls  day_charge  eve_mins  \
# 1           3         2.70     265.1        110       45.07     197.4
# 2           3         3.70     161.6        123       27.47     195.5
# 3           5         3.29     243.4        114       41.38     121.2
# 4           7         1.78     299.4         71       50.90      61.9
# 5           3         2.73     166.7        113       28.34     148.3
#
#    eve_calls  eve_charge  night_mins  night_calls  night_charge  \
# 1         99       16.78       244.7           91         11.01
# ...

# %%
telecom.dtypes
# Out:
# account_length      int64
# voice_plan          int32
# voice_messages      int64
# intl_plan           int32
# intl_mins         float64
# intl_calls          int64
# intl_charge       float64
# day_mins          float64
# day_calls           int64
# day_charge        float64
# eve_mins          float64
# eve_calls           int64
# eve_charge        float64
# night_mins        float64
# night_calls         int64
# night_charge      float64
# customer_calls      int64
# churn               int32
# dtype: object

# %%
# To reinforce our insights about the data symmetry and their outliers, we can plot some boxplots

plt.figure(dpi=250)
telecom.plot(kind='box', subplots=True, layout=(6,6), figsize=(10,15), sharex=False, sharey=False, color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# - *In above box plots we see that the outliers present in telecom churn dataset.*

# %%
# Calculate the first and third quartiles for numerical columns
q1 = telecom.quantile(0.25)
q3 = telecom.quantile(0.75)
iqr = q3 - q1

# Define outlier threshold as Q3 + 1.5*IQR
outlier_threshold = q3 + 1.5*iqr

# Count the number of outliers in the entire dataset
num_outliers = (telecom > outlier_threshold).sum().sum()

# Calculate the percentage of outliers in the dataset
percent_outliers = num_outliers / telecom.size * 100

print(f"Percentage of outliers in the entire dataset: {percent_outliers:.2f}%")
# Out:
# Percentage of outliers in the entire dataset: 2.22%

# %% [markdown]
# - **Reducing outliers with the help of `IQR method`.**

# %%
# Apply outlier detection and treatment on all numerical columns 
numerical_cols = telecom.select_dtypes(include=['int64', 'float64']).columns

for i in numerical_cols:
    Q1 = telecom[i].quantile(0.25)
    Q3 = telecom[i].quantile(0.75)
    IQR = Q3 - Q1
    Outer_layer = Q3 + 1.5 * IQR
    Lower_layer = Q1 - 1.5 * IQR

    telecom.loc[telecom[i] > Outer_layer, i] = Outer_layer
    telecom.loc[telecom[i] < Lower_layer, i] = Lower_layer

# %%
# Checking that the outliers are reduced or not

plt.figure(dpi=250)
telecom.plot(kind='box', subplots=True, layout=(6,6), figsize=(10,15), sharex=False, sharey=False, color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# - *In above graph we see that outliers are reduced with the help of IQR method.*

# %% [markdown]
# ## Histogram Plots :
# - *The easiest way to take a look at the distribution of a numerical variable is to plot its histogram using the DataFrame's method `hist()`.*

# %%
telecom.hist(figsize=(20,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# - *In above histograms we see that the some columns are normally distributed, some columns has right skeweed & some has left skeweed.*

# %%
# Checking customer calls wise churn by using countplot 

sns.countplot(x="customer_calls", hue="churn", data=telecom)
# Out:
# <AxesSubplot: xlabel='customer_calls', ylabel='count'>

# %% [markdown]
# - *In above graph, we see that the churn rate increases significantly after `3 calls`.*

# %%
# Relation between intl.calls & voice.plan

_, axes = plt.subplots(1, 2, sharey=True, figsize=(10, 4))

sns.countplot(x="intl_plan", hue="churn", data=telecom, ax=axes[0])
sns.countplot(x="voice_plan", hue="churn", data=telecom, ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# - *when chustomers having `intl.plan`, then the churn rate is much higher.*
# - *We do not observe the same effect with `voice.plan`.*

# %%
# Value counts for voice_plan column
telecom['voice_plan'].value_counts()
# Out:
# 0    3677
# 1    1323
# Name: voice_plan, dtype: int64

# %% [markdown]
# - *1323 users having voice plan & 3677 users are not using voice plan.*

# %%
plt.figure(figsize=(20,15),dpi=250)

# extract the values for the four columns in charge distribution
intl_charge = telecom['intl_charge'].sum()
day_charge = telecom['day_charge'].sum()
eve_charge = telecom['eve_charge'].sum()
night_charge = telecom['night_charge'].sum()

# create a pie chart for charge distribution
plt.subplot(1, 3, 1)
labels1 = ['intl_charge', 'day_charge', 'eve_charge', 'night_charge']
values1 = [intl_charge, day_charge, eve_charge, night_charge]
plt.pie(values1, labels=labels1)
plt.title('Charge Distribution')

# extract the values for the four columns in minutes distribution
intl_mins = telecom['intl_mins'].sum()
day_mins = telecom['day_mins'].sum()
eve_mins = telecom['eve_mins'].sum()
night_mins = telecom['night_mins'].sum()

# create a pie chart for minutes distribution
plt.subplot(1, 3, 2)
labels2 = ['intl_mins', 'day_mins', 'eve_mins', 'night_mins']
values2 = [intl_mins, day_mins, eve_mins, night_mins]
plt.pie(values2, labels=labels2)
plt.title('Minutes Distribution')

# extract the values for the five columns in calls distribution
intl_calls = telecom['intl_calls'].sum()
day_calls = telecom['day_calls'].sum()
eve_calls = telecom['eve_calls'].sum()
night_calls = telecom['night_calls'].sum()
customer_calls = telecom['customer_calls'].sum()

# create a pie chart for calls distribution
plt.subplot(1, 3, 3)
labels3 = ['intl_calls', 'day_calls', 'eve_calls', 'night_calls','customer_calls']
values3 = [intl_calls, day_calls, eve_calls, night_calls, customer_calls]
plt.pie(values3, labels=labels3)
plt.title('Calls Distribution')

# display the combined plot
plt.show()

# %% [markdown]
# **Observations :**
# - *In Charge distribution pie chart, we see that the day charges are high than any other charges & international charges are low than compare to other charges.*
# - *In minutes distribution pie chart, we see that the evening & nights minutes are equal, but international minutes are very low.*
# - *In calls distribution pie chart, we see that the evening & night calls are equal, but the international calls are low & customer calls are very low.*

# %%
# Group the data by account.length & churn status and count the number of rows
grouped_data = telecom.groupby(['account_length', 'churn']).size().reset_index(name='count')

# Pivot the data to have account.length as index, churn status as columns, and count as values
pivot_data = grouped_data.pivot(index='account_length', columns='churn', values='count')

# Create a stacked bar chart with the pivot data
ax = pivot_data.plot(kind='bar', stacked=True, figsize=(30,10))

# Set the title and axis labels
ax.set_title('Churned Customers by Account Length')
ax.set_xlabel('Account Length')
ax.set_ylabel('Number of Customers')

plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **As we see in above barplot :**
# - *People with account length 90 are the most.*
# - *People with account length 5,9,8,9,10,15,18,20,22,156,164,165,183,186,187,189,190,191,192,195,196,199,202,204,205 are not churned.*

# %%
sns.lmplot(x='day_mins', y='night_mins', hue='churn', data=telecom, fit_reg=False);

# %% [markdown]
# - *As we see in above scatter plot, day_mins & night_mins are increases then customers are churned*

# %% [markdown]
# # Feature Selection :

# %% [markdown]
# ## Correlation Analysis :

# %% [markdown]
# - *For understanding about correlation, we use `heatmap()` for visualize the correlation between each columns.*

# %%
plt.figure(figsize=(20,7))
sns.heatmap(telecom.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# - *In above heatmap we see that the high multicollinearity occurs in `intl_mins, intl_charge, day_mins, day_charge, eve_mins, eve_charge, night_mins, night_charge` columns.*

# %% [markdown]
# - *For reducing multicollinearity, we calculating VIF values for this columns.*

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Select the columns for which VIF values need to be calculated
cols = ['intl_mins', 'intl_charge', 'day_mins', 'day_charge', 'eve_mins', 'eve_charge', 'night_mins', 'night_charge']

# Calculate the VIF values for the selected columns
X = telecom[cols]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# Sort the VIF values in decreasing order
vif_sorted = vif.sort_values('VIF Factor', ascending=False)

# Show the VIF values
vif_sorted
# Out:
#      VIF Factor      features
# 7  1.058614e+07  night_charge
# 6  1.058583e+07    night_mins
# 1  8.636260e+05   intl_charge
# 0  8.625603e+05     intl_mins
# 3  2.635939e+04    day_charge
# 2  2.635581e+04      day_mins
# 4  3.610960e+03      eve_mins
# 5  3.599227e+03    eve_charge

# %% [markdown]
# - *Compare VIF values between charge & mins columns.*
# - *Drop those relevent columns which shows high VIF values.*

# %%
# Droping columns which is high VIF value
telecom.drop(['night_charge','intl_charge','day_charge','eve_mins'], axis=1, inplace=True)

# Checking that the multicollinearity is reduced or not
plt.figure(figsize=(20,6))
sns.heatmap(telecom.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# - *As we see in above heatmap multicollinearity is reduced.*

# %%
# After reducing multicollinearity, checking the dimensions of dataset

telecom.shape
# Out:
# (5000, 14)

# %% [markdown]
# - *After reducing multicollinearity, we have 5000 rows & 14 columns in telecom dataset.*

# %%
# Defining independent (x) & dependent (y) variables for feature selection

x = telecom.iloc[:,:-1]
y = telecom['churn']

# %% [markdown]
# ## Univariate Selection :

# %%
# Using chisquare for feature selection
test = SelectKBest(score_func=chi2, k=10)

# Fitting independent & dependent variables in SelectKBest
chi_score = test.fit(x,y)

# Creating dataframe for scores of chisquare
uni_select = pd.DataFrame()
uni_select['Features'] = x.columns
uni_select['Chi2_scores'] = chi_score.scores_

# Show dataframe with sorted Chi_scores in decreasing order
uni_select.sort_values('Chi2_scores', ascending=False)
# Out:
#           Features  Chi2_scores
# 6         day_mins  3419.438136
# 2   voice_messages  1127.015169
# 3        intl_plan   303.963357
# 10      night_mins   132.451969
# 12  customer_calls   103.570015
# 1       voice_plan    45.058340
# 9       eve_charge    41.927232
# 0   account_length    34.895782
# 5       intl_calls    16.183508
# 4        intl_mins    13.652515
# 7        day_calls     5.351854
# 8        eve_calls     0.977776
# 11     night_calls     0.940669

# %%
# Visualize the Univariate Selection

sns.barplot(x='Chi2_scores', y='Features', data=uni_select)
# Out:
# <AxesSubplot: xlabel='Chi2_scores', ylabel='Features'>

# %% [markdown]
# ## Tree Based Method :

# %%
# Creating object for DecisionTreeClassifier()
dt = DecisionTreeClassifier()

# Fitting independent & dependent variables in DecisionTreeClassifier
dt_score = dt.fit(x,y)

# Creating dataframe for Tree Based Method
tree_method = pd.DataFrame()
tree_method['Features'] = x.columns
tree_method['Tree_scores'] = pd.Series(dt_score.feature_importances_).sort_values(ascending=False)

# Show dataframe with sorted by Tree_scores in decreasing order
tree_method.sort_values('Tree_scores', ascending=False)
# Out:
#           Features  Tree_scores
# 6         day_mins     0.254596
# 9       eve_charge     0.138416
# 4        intl_mins     0.110329
# 12  customer_calls     0.107160
# 5       intl_calls     0.082162
# 10      night_mins     0.077516
# 3        intl_plan     0.067817
# 2   voice_messages     0.064329
# 7        day_calls     0.036199
# 11     night_calls     0.022034
# 0   account_length     0.020926
# 8        eve_calls     0.017691
# 1       voice_plan     0.000824

# %%
# Visualize the tree based method

sns.barplot(x='Tree_scores', y='Features', data=tree_method)
# Out:
# <AxesSubplot: xlabel='Tree_scores', ylabel='Features'>

# %% [markdown]
# ## Recursive Feature Elimination `[RFE]` :

# %%
# Creating object for LogisticRegrassion()
lg = LogisticRegression()

# Creating object for RFE with LogisticRegression estimator
rfe = RFE(estimator=lg, n_features_to_select=10)

# Fitting independent & dependent variables into RFE
rfe.fit(x,y)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=10)

# %%
# Final number of features selected by RFE after recursively eliminating the least important features.
rfe.n_features_
# Out:
# 10

# %%
rfe.support_
# Out:
# array([False,  True,  True,  True,  True,  True,  True, False,  True,
#         True, False,  True,  True])

# %% [markdown]
# - *It is a boolean array that indicates whether each feature in the input data was selected or not by the `RFE` algorithm.*

# %%
# Creating dataframe for features, Support & ranking
rfe_data = pd.DataFrame({'Features': x.columns, 'Support': rfe.support_, 'Ranking': rfe.ranking_})

# Sorting the data by the "Ranking" column
rfe_data = rfe_data.sort_values(by='Ranking')

# Showing dataframe
rfe_data
# Out:
#           Features  Support  Ranking
# 1       voice_plan     True        1
# 2   voice_messages     True        1
# 3        intl_plan     True        1
# 4        intl_mins     True        1
# 5       intl_calls     True        1
# 6         day_mins     True        1
# 8        eve_calls     True        1
# 9       eve_charge     True        1
# 11     night_calls     True        1
# 12  customer_calls     True        1
# 7        day_calls    False        2
# 0   account_length    False        3
# 10      night_mins    False        4

# %%
# Create a bar plot of the features and their rankings
plt.bar(rfe_data['Features'], rfe_data['Ranking'])
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Ranking')
plt.title('Recursive Feature Elimination Rankings')
plt.show()

# %% [markdown]
# - *In above graph, only `First` ranked columns are important than other columns.*

# %% [markdown]
# # T-distributed Stochastic Neighbor Embedding `[t-SNE]` :

# %%
from sklearn.manifold import TSNE

# Defining t-SNE model with 2 components (for 2D visualization)
tsne = TSNE(n_components=2)

# Fit & transform the indepentent feature X
X_tsne = tsne.fit_transform(x)

# Show transformed output
X_tsne
# Out:
# array([[ 53.304245 , -24.04672  ],
#        [ 33.225857 ,  36.0908   ],
#        [ -5.173775 , -54.46514  ],
#        ...,
#        [-12.036096 ,  23.188124 ],
#        [ 41.017216 ,   5.2295513],
#        [-59.757416 ,  14.035493 ]], dtype=float32)

# %%
# Visualize the t-SNE plot
plt.figure(figsize=(20,10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y)
plt.show()

# %% [markdown]
# # Predictive Power Score `[PPS]` :

# %%
import ppscore as pps

# Creating an empty dictionary to store the PPS scores for each pair of columns
pps_scores = {}

# Iterate through all the columns in the dataframe
for col in telecom.columns:

    # Calculating the PPS scores for the current column & the target column "churn"
    if col != 'churn':
        pps_score = pps.score(df=telecom, x=col, y='churn')['ppscore']
        pps_scores[(col, 'churn')] = pps_score

# Print the PPS scores for each pair of columns
for col_pair, pps_score in pps_scores.items():
    print(f"PPS between columns {col_pair} & 'churn': {pps_score}")
# Out:
# PPS between columns ('account_length', 'churn') & 'churn': 0
# PPS between columns ('voice_plan', 'churn') & 'churn': 0
# PPS between columns ('voice_messages', 'churn') & 'churn': 0
# PPS between columns ('intl_plan', 'churn') & 'churn': 0
# PPS between columns ('intl_mins', 'churn') & 'churn': 0
# PPS between columns ('intl_calls', 'churn') & 'churn': 0
# PPS between columns ('day_mins', 'churn') & 'churn': 0
# PPS between columns ('day_calls', 'churn') & 'churn': 0
# PPS between columns ('eve_calls', 'churn') & 'churn': 0
# PPS between columns ('eve_charge', 'churn') & 'churn': 0
# PPS between columns ('night_mins', 'churn') & 'churn': 0
# PPS between columns ('night_calls', 'churn') & 'churn': 0
# PPS between columns ('customer_calls', 'churn') & 'churn': 0

# %% [markdown]
# # Final Dataset :

# %% [markdown]
# - *Selecting only comman columns from `univariate selection, tree based method & RFE`.*

# %%
# Selecting only comman columns
final_df = telecom[['account_length','voice_messages','intl_plan','intl_mins','intl_calls', 
                   'day_mins','eve_charge','night_mins','customer_calls','churn']]

# Show first 5 rows from final dataset
final_df.head()
# Out:
#    account_length  voice_messages  intl_plan  intl_mins  intl_calls  day_mins  \
# 1             128            25.0          0       10.0         3.0     265.1
# 2             107            26.0          0       13.7         3.0     161.6
# 3             137             0.0          0       12.2         5.0     243.4
# 4              84             0.0          1        6.6         7.0     299.4
# 5              75             0.0          1       10.1         3.0     166.7
#
#    eve_charge  night_mins  customer_calls  churn
# 1       16.78       244.7             1.0      0
# 2       16.62       254.4             1.0      0
# 3       10.30       162.6             0.0      0
# 4        5.50       196.9             2.0      0
# 5       12.61       186.9             3.0      0

# %%
# Dimensions of finalize data
final_df.shape
# Out:
# (5000, 10)

# %% [markdown]
# # Model building :

# %%
# Defining independent (x) & dependent (y) variables for model building purpose

x = final_df.iloc[:,:-1]
y = final_df['churn']

# %%
# Target column value count
y.value_counts()
# Out:
# 0    4293
# 1     707
# Name: churn, dtype: int64

# %% [markdown]
# ## Balancing Data :
# - **As we see in above target column value counts, the data is imbalanced.**
# - **For balancing that data we use `RandomOverSampler()`.**

# %%
from imblearn.over_sampling import RandomOverSampler

# Creating a RandomOverSampler object
ros = RandomOverSampler()

# Fitting the RandomOverSampler to the data & perform the oversampling
x, y = ros.fit_resample(x, y)

# Verify that the dataset is balanced
print(y.value_counts())
# Out:
# 0    4293
# 1    4293
# Name: churn, dtype: int64

# %% [markdown]
# ***Standardize features by removing the mean and scaling to unit variance.***

# %%
from sklearn.preprocessing import StandardScaler

# Creating object for StandardScaler()
sc = StandardScaler()

# Standardizing independent (x) variables
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# Splitting data into train & test sets to avoid overfitting
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25,random_state=1)

# %% [markdown]
# ## Logistic Regression :

# %%
from sklearn.linear_model import LogisticRegression

# Creating object for LogisticRegression()
lg = LogisticRegression()

# Fitting the model on training data
lg.fit(xtrain,ytrain)

# Prediction
lg_pred = lg.predict(xtest)

# %%
# Training & Testing accuracy
print('Training Accuracy : ', lg.score(xtrain,ytrain))
print('Testing Accuracy : ', lg.score(xtest,ytest))
# Out:
# Training Accuracy :  0.7384687063208573
# Testing Accuracy :  0.7298556124825337

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Showing the main classification metrics
print(classification_report(ytest,lg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74      1068
#            1       0.74      0.70      0.72      1079
#
#     accuracy                           0.73      2147
#    macro avg       0.73      0.73      0.73      2147
# weighted avg       0.73      0.73      0.73      2147

# %%
# Computing confusion matrix to evaluate the accuracy of a classification.

sns.heatmap(confusion_matrix(ytest,lg_pred), annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Values')

# %%
# Accuracy classification score.
accuracy_score(ytest,lg_pred)
# Out:
# 0.7298556124825337

# %% [markdown]
# # Random Forests :

# %%
from sklearn.ensemble import RandomForestClassifier

# Create object for RandomForestClassifier()
rf = RandomForestClassifier()

# Fitting the model on training data
rf.fit(xtrain,ytrain)

# Prediction
rf_pred = rf.predict(xtest)

# %%
# Training & Testing accuracy
print('Training Accuracy : ', rf.score(xtrain,ytrain))
print('Testing Accuracy : ', rf.score(xtest,ytest))
# Out:
# Training Accuracy :  1.0
# Testing Accuracy :  0.9939450395901258

# %%
# Showing the main classification metrics
print(classification_report(ytest,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1068
#            1       0.99      1.00      0.99      1079
#
#     accuracy                           0.99      2147
#    macro avg       0.99      0.99      0.99      2147
# weighted avg       0.99      0.99      0.99      2147

# %%
# Compute confusion matrix to evaluate the accuracy of a classification.

sns.heatmap(confusion_matrix(ytest,rf_pred), annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Values')

# %%
# Accuracy classification score.
accuracy_score(ytest,rf_pred)
# Out:
# 0.9939450395901258

# %% [markdown]
# # GradientBoostingClassifier :

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Create object for GradientBoostingClassifier()
gb = GradientBoostingClassifier()

# Fitting the model on training data
gb.fit(xtrain,ytrain)

# Prediction
gb_pred = gb.predict(xtest)

# %%
# Training & Testing accuracy
print('Training Accuracy : ', gb.score(xtrain,ytrain))
print('Testing Accuracy : ', gb.score(xtest,ytest))
# Out:
# Training Accuracy :  0.9212610653828234
# Testing Accuracy :  0.9026548672566371

# %%
# Showing the main classification metrics
print(classification_report(ytest,gb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      1068
#            1       0.94      0.86      0.90      1079
#
#     accuracy                           0.90      2147
#    macro avg       0.91      0.90      0.90      2147
# weighted avg       0.91      0.90      0.90      2147

# %%
# Compute confusion matrix to evaluate the accuracy of a classification.

sns.heatmap(confusion_matrix(ytest,gb_pred), annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Values')

# %%
# Accuracy classification score.
accuracy_score(ytest,gb_pred)
# Out:
# 0.9026548672566371

# %% [markdown]
# # Support Vector Machines [SVM] :

# %%
from sklearn import svm

# Create object for svm()
svm = svm.SVC()

# Fitting the model on training data
svm.fit(xtrain,ytrain)

# Prediction
svm_pred = svm.predict(xtest)

# %%
# Training & Testing accuracy
print('Training Accuracy : ', svm.score(xtrain,ytrain))
print('Testing Accuracy : ', svm.score(xtest,ytest))
# Out:
# Training Accuracy :  0.907128436092561
# Testing Accuracy :  0.8896134140661388

# %%
# Showing the main classification metrics
print(classification_report(ytest,svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      1068
#            1       0.90      0.88      0.89      1079
#
#     accuracy                           0.89      2147
#    macro avg       0.89      0.89      0.89      2147
# weighted avg       0.89      0.89      0.89      2147

# %%
# Compute confusion matrix to evaluate the accuracy of a classification.

sns.heatmap(confusion_matrix(ytest,svm_pred), annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Values')

# %%
# Accuracy classification score.
accuracy_score(ytest,svm_pred)
# Out:
# 0.8896134140661388

# %% [markdown]
# # Decision Tree :

# %%
from sklearn.tree import DecisionTreeClassifier

# Create object for DecisionTreeClassifier()
dt = DecisionTreeClassifier()

# Fitting the model on training data
dt.fit(xtrain,ytrain)

# Prediction
dt_pred = dt.predict(xtest)

# %%
# Training & Testing accuracy
print('Training Accuracy : ', dt.score(xtrain,ytrain))
print('Testing Accuracy : ', dt.score(xtest,ytest))
# Out:
# Training Accuracy :  1.0
# Testing Accuracy :  0.9715882626921285

# %%
# Showing the main classification metrics
print(classification_report(ytest,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97      1068
#            1       0.95      1.00      0.97      1079
#
#     accuracy                           0.97      2147
#    macro avg       0.97      0.97      0.97      2147
# weighted avg       0.97      0.97      0.97      2147

# %%
# Compute confusion matrix to evaluate the accuracy of a classification.

sns.heatmap(confusion_matrix(ytest,dt_pred), annot=True)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Values')

# %%
# Accuracy classification score.
accuracy_score(ytest,dt_pred)
# Out:
# 0.9715882626921285

# %%
# Creating dataframe for created models & their accuracy
model_acc = pd.DataFrame()

# Column for all created models
model_acc['Model'] = ['Logistic Regrassion','Random Forests','GradientBoostingClassifier','SVM','DecisionTreeClassifier']

# Column for their accuracy
model_acc['Accuracy'] = [accuracy_score(ytest,lg_pred), accuracy_score(ytest,rf_pred), accuracy_score(ytest,gb_pred), 
                        accuracy_score(ytest,svm_pred), accuracy_score(ytest,dt_pred)]

# Show the Dataframe
model_acc
# Out:
#                         Model  Accuracy
# 0         Logistic Regrassion  0.729856
# 1              Random Forests  0.993945
# 2  GradientBoostingClassifier  0.902655
# 3                         SVM  0.889613
# 4      DecisionTreeClassifier  0.971588

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=model_acc['Model'], y=model_acc['Accuracy'], data=model_acc)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### `Random Forests` algorithm gives high accuracy than other algorithms.
# - **Performing `KFold cross-validation` & hyperparameter tunning on `Random Forests` algorithm.**

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import roc_auc_score, roc_curve

# Evaluate the model's performance
print(classification_report(ytest, rf_pred))
print("AUC-ROC Score:", roc_auc_score(ytest, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1068
#            1       0.99      1.00      0.99      1079
#
#     accuracy                           0.99      2147
#    macro avg       0.99      0.99      0.99      2147
# weighted avg       0.99      0.99      0.99      2147
#
# AUC-ROC Score: 0.9939138576779026

# %%
# Performing k-fold cross-validation to check the model's generalization performance
kfold = KFold(n_splits=5, random_state=1, shuffle=True)
cv_scores = cross_val_score(rf, x, y, cv=kfold)
print("KFold Cross-validation scores :", cv_scores)
print("\nKFold Cross-validation Accuracy Score : {:.2f}%".format(cv_scores.mean() * 100))
# Out:
# KFold Cross-validation scores : [0.99359721 0.99068142 0.99592312 0.98893419 0.99068142]
#
# KFold Cross-validation Accuracy Score : 99.20%

# %%
from sklearn.model_selection import GridSearchCV

# Tune hyperparameters using grid search
param_grid = {'n_estimators': [100, 300, 500],
              'criterion' : ["gini", "entropy"],
              'max_depth': [5, 10, 15],
              'min_samples_split': [2, 5, 10]}

# Exhaustive search over specified parameter values for an estimator.
grid = GridSearchCV(rf, param_grid = param_grid)

# Fitting data into grid
grid.fit(xtrain, ytrain)

# Print the best hyperparameters
print("Best hyperparameters :", grid.best_params_)
# Out:
# Best hyperparameters : {'criterion': 'gini', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Fitting the model with the best hyperparameters & evaluate performance
rf_best = RandomForestClassifier(**grid.best_params_)

# Fitting data into tunned model
rf_best.fit(xtrain, ytrain)

# Prediction 
rf_pred_best = rf_best.predict(xtest)

print("Best model performance :")
print("\nAUC-ROC Score :", roc_auc_score(ytest, rf_pred_best))
print(classification_report(ytest, rf_pred_best))
# Out:
# Best model performance :
#
# AUC-ROC Score : 0.9874072782053018
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1068
#            1       0.98      0.99      0.99      1079
#
#     accuracy                           0.99      2147
#    macro avg       0.99      0.99      0.99      2147
# weighted avg       0.99      0.99      0.99      2147

# %%
# Calculating accuracy score for tunned random forests model
acc = accuracy_score(ytest, rf_pred_best)

# Print accuracy as a percentage
print("Accuracy : {:.2f}%".format(acc * 100))
# Out:
# Accuracy : 98.74%

# %%
from sklearn.metrics import auc

# The true labels in ytest & predicted probabilities in rf_pred_best

'''The roc_curve function is used to compute the True Positive Rate (TPR) & False Positive Rate (FPR)
at various probability thresholds. These values are stored in tpr, fpr & thresholds.'''

fpr, tpr, thresholds = roc_curve(ytest, rf_pred_best) # Computing Receiver Operating Characteristic (ROC)
roc_auc = auc(fpr, tpr) # Computing Area Under the Curve (AUC)

# Plotting the ROC curve
plt.plot(fpr, tpr, color='blue', label='ROC Curve (%0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# - ***ROC curve shows a perfect classifier, it means that the `Random forests` model is able to perfectly distinguish between the positive & negative classes.***

# %% [markdown]
# # Save the model :

# %%
import pickle

# %%
# Save the trained model to a file
with open('Telecom_Churn_Prediction.pkl', 'wb') as file:
    pickle.dump(rf_best, file)

# %%
final_df.head(20)
# Out:
#     account_length  voice_messages  intl_plan  intl_mins  intl_calls  \
# 1              128            25.0          0       10.0         3.0
# 2              107            26.0          0       13.7         3.0
# 3              137             0.0          0       12.2         5.0
# 4               84             0.0          1        6.6         7.0
# 5               75             0.0          1       10.1         3.0
# 6              118             0.0          1        6.3         6.0
# 7              121            24.0          0        7.5         7.0
# 8              147             0.0          1        7.1         6.0
# 9              117             0.0          0        8.7         4.0
# 10             141            37.0          1       11.2         5.0
# 11              65             0.0          0       12.7         6.0
# 12              74             0.0          0        9.1         5.0
# 13             168             0.0          0       11.2         2.0
# ...
